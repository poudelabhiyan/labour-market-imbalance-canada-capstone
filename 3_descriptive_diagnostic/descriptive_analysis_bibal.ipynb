# %% [markdown]
# # Descriptive Analysis — Labour Market Imbalance in Canada
#
# **Contributor:** Bibal Adhikari
# **Sprint:** 3 — Descriptive + Diagnostic
#
# ## Objectives
# - Explore employment trends (2015–2024)
# - Visualize unemployment and job vacancies
# - Identify COVID and post-COVID patterns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")
